# %%
import pickle 
import numpy as np

# %%
data_path = '../data/'

# read and print the previous datasets 
filename = data_path + 'GPT_ndp.pkl'

with open(filename, 'rb') as f:
    data = pickle.load(f)

data
# Out:
# {'Economic': {'Taxation': {'position': 0.8},
#   'Spending': {'position': 0.7},
#   'MinimumWage': {'position': 0.9},
#   'FiscalDiscipline': {'position': 0.6},
#   'LabourPolicy': {'position': 0.8}},
#  'Social': {'Healthcare': {'position': 1.0},
#   'Education': {'position': 1.0},
#   'CurriculumControl': {'position': 1.0},
#   'Housing': {'position': 1.0},
#   'Indigenous': {'position': 1.0},
#   'Immigration': {'position': 0.0},
#   'LGBTQ': {'position': 0.9},
#   'Drugs': {'position': 0.7},
#   'DEI': {'position': 0.8}},
#  'Environment': {'Emissions': {'position': 0.9},
#   'CarbonTax': {'position': 0.8},
#   'FossilFuels': {'position': 0.8},
#   'GreenInvestment': {'position': 0.9}},
#  'Foreign': {'SpendingM': {'position': -0.5},
#   'RefugeePolicy': {'position': 0.5},
#   'Aid': {'position': 0.5},
#   'Trade': {'position': -0.3},
#   'IsraelPalestine': {'position': 0.8},
#   'UkraineRussia': {'position': 0.7}},
#  'Justice': {'CriminalJustice': {'position': 0.8},
# ...

# %% [markdown]
# # Updating Conservative Positions

# %% [markdown]
# GPT Response:
# Economic:
# Taxation:
#
# The Conservative party is focusing on reducing taxes (e.g., reducing the lowest income tax rate to 12.75% and increasing the TFSA contribution limit). This suggests a more right-leaning stance on taxation.
#
# Updated Position: -0.7 (slightly more right-leaning than before).
#
# Spending:
#
# The party has promised to cut government spending, focusing on reductions in foreign aid, CBC defunding, and a leaner federal public service.
#
# Updated Position: -0.7 (stronger emphasis on fiscal conservatism).
#
# MinimumWage:
#
# There is no direct mention of minimum wage, but their general stance on reducing taxes and limiting government intervention implies a more market-driven approach.
#
# Position Remains: 0.0.
#
# FiscalDiscipline:
#
# The Conservative party has mentioned strict cuts to spending in areas like government programs and foreign aid. This is in line with low debt tolerance.
#
# Updated Position: -0.7 (more stringent fiscal discipline).
#
# LabourPolicy:
#
# The platform focuses on reducing public service spending and emphasizes a more market-oriented approach, with no new major labour protections.
#
# Updated Position: -0.2 (slightly more market-friendly).
#
# Social:
# Healthcare:
#
# The platform does not support universal public healthcare but focuses on alternatives such as abolishing supervised consumption sites and promoting recovery/rehab.
#
# Updated Position: -0.6 (more privatized health system orientation).
#
# Education:
#
# No major changes, with an implied focus on reducing the role of government in education (e.g., cost reduction measures for certain programs).
#
# Position Remains: 0.0.
#
# CurriculumControl:
#
# No explicit change, though the general conservative approach may imply support for less government intervention in education.
#
# Position Remains: 0.0.
#
# Housing:
#
# The Conservatives focus on cutting the GST for new homes and incentivizing more construction through municipalities, which is more market-driven.
#
# Updated Position: -0.2 (less emphasis on government intervention, more market-driven).
#
# Indigenous:
#
# The Conservatives are in favour of repealing C-69 and promoting resource development in partnership with Indigenous communities, suggesting a more market-driven approach to Indigenous affairs.
#
# Updated Position: -0.3 (leaning more towards development and less on nation-to-nation status).
#
# Immigration:
#
# The Conservatives want to reduce immigration and grant provinces more control over temporary immigrants. This reflects a tighter stance on immigration.
#
# Updated Position: -0.8 (more restrictive).
#
# LGBTQ:
#
# No major changes on LGBTQ issues, but given their general stance on limiting government intervention in social issues, the position remains more conservative.
#
# Position Remains: -0.5.
#
# Drugs:
#
# Their position on drug use leans toward criminalization, with a focus on recovery programs and mandatory drug treatment for minors.
#
# Updated Position: -0.6 (more restrictive stance).
#
# DEI:
#
# The Conservative party does not support DEI programs, with a preference for individual merit and non-interventionist approaches.
#
# Updated Position: -0.8 (strong opposition to DEI).
#
# Environment:
# Emissions:
#
# The platform emphasizes repealing carbon pricing and not setting emission reduction targets.
#
# Updated Position: -1.0 (more lenient on emissions).
#
# CarbonTax:
#
# Strong opposition to carbon pricing, with no carbon tax being a priority.
#
# Updated Position: -1.0 (strong opposition).
#
# FossilFuels:
#
# The Conservatives strongly support the oil and gas industry, including pipeline projects and oil exportation.
#
# Updated Position: -1.0 (strong support for fossil fuels).
#
# GreenInvestment:
#
# While the Conservatives support promoting clean energy, their focus is mainly on incentivizing the market rather than government-driven investments.
#
# Updated Position: 0.2 (more market-oriented than before).
#
# Foreign:
# SpendingM:
#
# The platform suggests increasing military spending and meeting NATO targets.
#
# Updated Position: 0.9 (no change).
#
# RefugeePolicy:
#
# The platform suggests a tighter refugee policy, reducing intake and focusing on national security.
#
# Updated Position: -0.2 (more restrictive).
#
# Aid:
#
# The Conservatives plan to slash foreign aid and focus more on domestic priorities.
#
# Updated Position: -1.0 (strong opposition to foreign aid).
#
# Trade:
#
# They continue to support free trade, especially with the U.S., and their stance on tariffs supports trade liberalization.
#
# Position Remains: 0.5.
#
# IsraelPalestine:
#
# No changes, still unconditional support for Israel.
#
# Position Remains: 0.0.
#
# UkraineRussia:
#
# The Conservatives continue their strong support for Ukraine in the conflict with Russia.
#
# Position Remains: 0.8.
#
# Justice:
# CriminalJustice:
#
# The Conservatives propose tough-on-crime measures like consecutive sentences and mandatory life sentences for drug traffickers.
#
# Updated Position: -1.0 (more punitive).
#
# FreeSpeech:
#
# Their position on free speech remains conservative, with minimal regulation.
#
# Position Remains: -0.9.
#
# PoliceReform:
#
# The Conservatives would prioritize law enforcement and policing as a solution to crime, with no major police reform.
#
# Position Remains: -0.7.
#
# ReligiousLiberty:
#
# They continue to strongly support freedom of religion, with no major changes.
#
# Position Remains: -0.6.
#
# Science:
# Research:
#
# The platform suggests private sector funding for research, with minimal public investment.
#
# Updated Position: -0.6 (more private sector driven).
#
# AI:
#
# The Conservatives don’t heavily regulate AI but might be supportive of market-led innovation.
#
# Position Remains: 0.5.
#
# Internet:
#
# No changes, supports market-driven infrastructure.
#
# Position Remains: -0.5.
#
# Privacy:
#
# The Conservatives are likely to maintain a more lenient stance on data collection and privacy, favoring security over regulation.
#
# Updated Position: 0.4 (slightly less strict).
#
# Governance:
# Electoral:
#
# The Conservatives maintain support for first-past-the-post and have not shown support for proportional representation.
#
# Position Remains: -0.9.
#
# Transparency:
#
# No significant changes on transparency, the focus remains on security and efficiency.
#
# Position Remains: 0.7.
#
# Federalism:
#
# The platform supports a stronger centralized government rather than increasing provincial autonomy.
#
# Position Remains: -0.5.

# %%
updated_conservative_positions = {
    'Economic': {
        'Taxation': {'position': -0.7},
        'Spending': {'position': -0.7},
        'MinimumWage': {'position': 0.0},
        'FiscalDiscipline': {'position': -0.7},
        'LabourPolicy': {'position': -0.2}
    },
    'Social': {
        'Healthcare': {'position': -0.6},
        'Education': {'position': 0.0},
        'CurriculumControl': {'position': 0.0},
        'Housing': {'position': -0.2},
        'Indigenous': {'position': -0.3},
        'Immigration': {'position': -0.8},
        'LGBTQ': {'position': -0.5},
        'Drugs': {'position': -0.6},
        'DEI': {'position': -0.8}
    },
    'Environment': {
        'Emissions': {'position': -1.0},
        'CarbonTax': {'position': -1.0},
        'FossilFuels': {'position': -1.0},
        'GreenInvestment': {'position': 0.2}
    },
    'Foreign': {
        'SpendingM': {'position': 0.9},
        'RefugeePolicy': {'position': -0.2},
        'Aid': {'position': -1.0},
        'Trade': {'position': 0.5},
        'IsraelPalestine': {'position': 0.0},
        'UkraineRussia': {'position': 0.8}
    },
    'Justice': {
        'CriminalJustice': {'position': -1.0},
        'FreeSpeech': {'position': -0.9},
        'PoliceReform': {'position': -0.7},
        'ReligiousLiberty': {'position': -0.6}
    },
    'Science': {
        'Research': {'position': -0.6},
        'AI': {'position': 0.5},
        'Internet': {'position': -0.5},
        'Privacy': {'position': 0.4}
    },
    'Governance': {
        'Electoral': {'position': -0.9},
        'Transparency': {'position': 0.7},
        'Federalism': {'position': -0.5}
    }
}

# %%
# save as a pickle file in platforms 
filename = data_path + 'GPT_conservative_platform.pkl'

with open(filename, 'wb') as f:
    pickle.dump(updated_conservative_positions, f)

# %% [markdown]
# # Updating Liberal Positions

# %% [markdown]
# Economic:
# Taxation:
#
# The Liberals are cutting taxes (e.g., reducing the lowest income tax bracket by one percentage point) and cancelling a proposed hike to the capital gains tax. This suggests a moderately left-leaning stance on taxation.
#
# Updated Position: 0.2 (slightly more left-leaning).
#
# Spending:
#
# The Liberals are introducing new initiatives such as increasing support for affordable housing and increasing health care investments. However, they also plan to balance operational spending within three years.
#
# Updated Position: 0.4 (slightly less expansive but still strong spending orientation).
#
# MinimumWage:
#
# No direct mention of minimum wage changes, though their general stance is supportive of social programs and increasing benefits for low-income individuals.
#
# Position Remains: 0.0.
#
# FiscalDiscipline:
#
# The Liberals focus on balancing the government's operational spending within three years but also propose significant new investments, especially in social programs.
#
# Updated Position: 0.3 (slightly more balanced, leaning toward moderate fiscal discipline).
#
# LabourPolicy:
#
# They support increasing funding for training programs and expanding access to apprenticeships. They also focus on enhancing interprovincial labour mobility.
#
# Updated Position: 0.6 (slightly more supportive of labor programs).
#
# Social:
# Healthcare:
#
# The Liberals are expanding health care coverage to include dental services for those aged 18-64 and are promising continued investments in health infrastructure.
#
# Updated Position: 0.9 (stronger public healthcare orientation).
#
# Education:
#
# The Liberals maintain their focus on public education and expanding health and dental care coverage. No direct changes, but they continue to advocate for improving access to education.
#
# Position Remains: 0.7.
#
# CurriculumControl:
#
# No major changes, but their focus on expanding access to public programs and ensuring inclusive education reflects a left-leaning stance.
#
# Position Remains: 0.0.
#
# Housing:
#
# The Liberals are increasing support for affordable housing and implementing measures to speed up development, including creating a new agency to oversee housing construction.
#
# Updated Position: 0.8 (stronger focus on public housing initiatives).
#
# Indigenous:
#
# The Liberals have committed to new funding for Indigenous-led infrastructure and continue their focus on partnerships with Indigenous communities.
#
# Updated Position: 0.9 (stronger support for Indigenous rights and development).
#
# Immigration:
#
# The Liberals plan to maintain immigration caps and assess Canada's capacity for newcomers.
#
# Updated Position: -0.3 (slightly more restrictive stance).
#
# LGBTQ:
#
# The Liberals remain committed to LGBTQ rights and inclusion, including funding for LGBTQ programs.
#
# Position Remains: 0.8.
#
# Drugs:
#
# The Liberals continue their focus on harm reduction and support for healthcare initiatives for those with addiction issues.
#
# Position Remains: 0.5.
#
# DEI:
#
# The Liberals remain strongly supportive of diversity, equity, and inclusion programs, including measures for 2SLGBTQ+ rights and reproductive health.
#
# Position Remains: 0.7.
#
# Environment:
# Emissions:
#
# The Liberals continue to advocate for carbon pricing, but they have also proposed some concessions, such as expanding energy projects and allowing Quebec to veto pipelines.
#
# Updated Position: 0.8 (strong support for emissions reductions with some trade-offs for energy projects).
#
# CarbonTax:
#
# The Liberals maintain support for carbon pricing, with measures like a carbon border adjustment to tax imports from countries without comparable pricing.
#
# Position Remains: 0.7.
#
# FossilFuels:
#
# The Liberals support building some pipelines and expanding energy projects but are also committed to phasing out fossil fuels in government buildings by 2030.
#
# Updated Position: 0.5 (more balanced approach toward fossil fuel use).
#
# GreenInvestment:
#
# The Liberals continue to invest heavily in green energy projects, including clean energy subsidies and infrastructure.
#
# Position Remains: 0.7.
#
# Foreign:
# SpendingM:
#
# The Liberals plan to increase defense spending to meet NATO targets but also aim to invest in international diplomacy and trade diversification.
#
# Updated Position: 0.7 (slightly more balanced defense spending).
#
# RefugeePolicy:
#
# The Liberals are focusing on maintaining support for refugees and asylum seekers, despite the caps on immigration.
#
# Updated Position: -0.2 (slightly more restrictive but still supportive).
#
# Aid:
#
# The Liberals are committed to maintaining foreign aid and focusing it on reproductive health, 2SLGBTQ+ issues, and climate programs.
#
# Position Remains: 0.5.
#
# Trade:
#
# The Liberals continue to support free trade and aim to diversify trade relationships, especially with the U.S.
#
# Position Remains: 0.8.
#
# IsraelPalestine:
#
# The Liberals continue their support for Israel, although they are focusing on diplomacy and multilateral negotiations.
#
# Position Remains: 0.3.
#
# UkraineRussia:
#
# The Liberals remain strong in their support for Ukraine, including sanctions against Russia.
#
# Position Remains: 0.9.
#
# Justice:
# CriminalJustice:
#
# The Liberals propose more punitive measures for serious crimes but are also emphasizing reforms such as shifting the burden of proof in certain criminal cases.
#
# Updated Position: -0.2 (more moderate stance).
#
# FreeSpeech:
#
# The Liberals are likely to continue their moderate stance on free speech, balancing freedom with regulatory oversight.
#
# Position Remains: 0.5.
#
# PoliceReform:
#
# The Liberals are focusing on both police reform and increasing funding for law enforcement.
#
# Updated Position: 0.4 (slightly more moderate stance).
#
# ReligiousLiberty:
#
# The Liberals maintain their support for secularism, but they continue to protect freedom of religion.
#
# Position Remains: 0.0.
#
# Science:
# Research:
#
# The Liberals continue their focus on publicly funded science and research initiatives.
#
# Position Remains: 0.9.
#
# AI:
#
# The Liberals remain supportive of both AI innovation and regulation.
#
# Position Remains: 0.8.
#
# Internet:
#
# The platform continues to support universal internet access.
#
# Position Remains: 0.0.
#
# Privacy:
#
# The Liberals emphasize privacy protections, with a focus on user rights and transparency.
#
# Position Remains: 0.0.
#
# Governance:
# Electoral:
#
# The Liberals support electoral reform but continue with the existing system for now.
#
# Updated Position: 0.3 (slightly more supportive of reform).
#
# Transparency:
#
# The Liberals continue to advocate for transparency in government.
#
# Position Remains: 0.4.
#
# Federalism:
#
# The Liberals maintain a moderate stance on federalism, with no major changes.
#
# Position Remains: 0.0.

# %%
updated_liberal_positions = {
    'Economic': {
        'Taxation': {'position': 0.2},
        'Spending': {'position': 0.4},
        'MinimumWage': {'position': 0.0},
        'FiscalDiscipline': {'position': 0.3},
        'LabourPolicy': {'position': 0.6}
    },
    'Social': {
        'Healthcare': {'position': 0.9},
        'Education': {'position': 0.7},
        'CurriculumControl': {'position': 0.0},
        'Housing': {'position': 0.8},
        'Indigenous': {'position': 0.9},
        'Immigration': {'position': -0.3},
        'LGBTQ': {'position': 0.8},
        'Drugs': {'position': 0.5},
        'DEI': {'position': 0.7}
    },
    'Environment': {
        'Emissions': {'position': 0.8},
        'CarbonTax': {'position': 0.7},
        'FossilFuels': {'position': 0.5},
        'GreenInvestment': {'position': 0.7}
    },
    'Foreign': {
        'SpendingM': {'position': 0.7},
        'RefugeePolicy': {'position': -0.2},
        'Aid': {'position': 0.5},
        'Trade': {'position': 0.8},
        'IsraelPalestine': {'position': 0.3},
        'UkraineRussia': {'position': 0.9}
    },
    'Justice': {
        'CriminalJustice': {'position': -0.2},
        'FreeSpeech': {'position': 0.5},
        'PoliceReform': {'position': 0.4},
        'ReligiousLiberty': {'position': 0.0}
    },
    'Science': {
        'Research': {'position': 0.9},
        'AI': {'position': 0.8},
        'Internet': {'position': 0.0},
        'Privacy': {'position': 0.0}
    },
    'Governance': {
        'Electoral': {'position': 0.3},
        'Transparency': {'position': 0.4},
        'Federalism': {'position': 0.0}
    }
}

# %%
# save 
filename = data_path + 'GPT_liberal_platform.pkl'

with open(filename, 'wb') as f:
    pickle.dump(updated_liberal_positions, f)

# %% [markdown]
# # Updated NDP Positions

# %% [markdown]
# Economic:
# Taxation:
#
# The NDP proposes higher taxes on high-net-worth individuals (e.g., a progressive wealth tax). They also aim to eliminate the GST on essentials and increase capital gains tax.
#
# Updated Position: 0.9 (strongly progressive stance).
#
# Spending:
#
# The NDP plans to significantly increase social spending, including universal pharmacare, increased housing investments, and child care.
#
# Updated Position: 0.9 (strong commitment to social programs).
#
# MinimumWage:
#
# The NDP has a strong stance on supporting workers, including the promise to raise untaxed income and implement rent control.
#
# Position Remains: 0.9.
#
# FiscalDiscipline:
#
# While the NDP advocates for increased spending on social issues, they also aim for a balanced budget in the long term and are willing to borrow when required.
#
# Updated Position: 0.7 (more focused on balance but still willing to invest).
#
# LabourPolicy:
#
# The NDP is highly supportive of labour rights, pledging to protect workers' benefits, raise caps on wage protection programs, and prioritize unionized workforces.
#
# Position Remains: 0.8.
#
# Social:
# Healthcare:
#
# The NDP is strongly committed to expanding public healthcare, including universal pharmacare, dental care, and mental health services.
#
# Position Remains: 1.0.
#
# Education:
#
# The NDP advocates for tuition-free education and expanding access to education across Canada.
#
# Position Remains: 1.0.
#
# CurriculumControl:
#
# The NDP supports inclusive, comprehensive education, which likely reflects their left-leaning stance.
#
# Position Remains: 1.0.
#
# Housing:
#
# The NDP is focused on building affordable housing, with promises to create millions of new homes and enforce rent control.
#
# Updated Position: 1.0 (strong emphasis on affordable housing).
#
# Indigenous:
#
# The NDP is committed to supporting Indigenous communities through initiatives like building housing and upholding UNDRIP.
#
# Position Remains: 1.0.
#
# Immigration:
#
# The NDP aims to ensure that immigration levels match Canada's needs and provide more protections for temporary workers.
#
# Updated Position: 0.2 (moderately supportive of immigration with a focus on fair treatment).
#
# LGBTQ:
#
# The NDP is a strong supporter of LGBTQ rights, advocating for greater protections and inclusivity.
#
# Position Remains: 0.9.
#
# Drugs:
#
# The NDP is focused on harm reduction and expanding healthcare supports for people with addiction.
#
# Updated Position: 0.8 (slightly stronger focus on harm reduction).
#
# DEI:
#
# The NDP supports proactive diversity, equity, and inclusion programs to address systemic disparities.
#
# Position Remains: 0.8.
#
# Environment:
# Emissions:
#
# The NDP supports aggressive action on emissions reduction but has some trade-offs, like opposing pipelines and promoting clean energy.
#
# Updated Position: 0.9 (strong focus on emission reductions).
#
# CarbonTax:
#
# The NDP supports carbon pricing but continues to adjust the policy for industrial emitters and imports.
#
# Position Remains: 0.8.
#
# FossilFuels:
#
# The NDP is focused on phasing out fossil fuel subsidies and investing in clean energy while opposing certain pipeline projects.
#
# Updated Position: 0.7 (moderate approach toward fossil fuel phase-out).
#
# GreenInvestment:
#
# The NDP supports heavy investments in green technologies and transitioning to clean energy.
#
# Position Remains: 0.9.
#
# Foreign:
# SpendingM:
#
# The NDP opposes large-scale defense spending and focuses on international peacekeeping.
#
# Updated Position: -0.5 (more focused on peacekeeping than military spending).
#
# RefugeePolicy:
#
# The NDP supports increasing refugee resettlement and prioritizing global humanitarian issues.
#
# Updated Position: 0.5 (strong support for refugees).
#
# Aid:
#
# The NDP aims to increase foreign aid to 0.7% of GDP, focusing on humanitarian and development issues.
#
# Position Remains: 0.5.
#
# Trade:
#
# The NDP is more skeptical of free trade and focuses on protecting Canadian jobs from international trade agreements.
#
# Updated Position: -0.3 (more protectionist stance).
#
# IsraelPalestine:
#
# The NDP supports recognizing Palestine as a state.
#
# Position Remains: 0.8.
#
# UkraineRussia:
#
# The NDP supports Ukraine in its conflict with Russia but maintains a focus on diplomatic solutions.
#
# Updated Position: 0.7 (strong but more balanced support).
#
# Justice:
# CriminalJustice:
#
# The NDP is focused on justice reforms, such as closing offshore tax havens and supporting workers' rights.
#
# Updated Position: 0.8 (stronger emphasis on corporate accountability and justice).
#
# FreeSpeech:
#
# The NDP continues to balance free speech with regulations on harmful content, ensuring protections for marginalized groups.
#
# Updated Position: 0.0 (more regulation in this area).
#
# PoliceReform:
#
# The NDP supports police reform and improving relations between police and marginalized communities.
#
# Position Remains: 0.7.
#
# ReligiousLiberty:
#
# The NDP supports religious freedoms but also maintains a focus on secularism in public institutions.
#
# Position Remains: 0.0.
#
# Science:
# Research:
#
# The NDP supports publicly funded research and scientific advancements.
#
# Position Remains: 0.8.
#
# AI:
#
# The NDP continues to support innovation while ensuring regulation and protections for workers.
#
# Position Remains: 0.9.
#
# Internet:
#
# The NDP focuses on universal internet access as a public good.
#
# Position Remains: 0.0.
#
# Privacy:
#
# The NDP is committed to enhancing privacy protections and data rights.
#
# Position Remains: 0.9.
#
# Governance:
# Electoral:
#
# The NDP supports proportional representation and electoral reform.
#
# Position Remains: 0.9.
#
# Transparency:
#
# The NDP continues to advocate for transparency and accountability in government.
#
# Position Remains: 0.7.
#
# Federalism:
#
# The NDP supports increasing provincial autonomy and decentralizing certain powers.
#
# Position Remains: 0.0

# %%
updated_ndp_positions = {
    'Economic': {
        'Taxation': {'position': 0.9},
        'Spending': {'position': 0.9},
        'MinimumWage': {'position': 0.9},
        'FiscalDiscipline': {'position': 0.7},
        'LabourPolicy': {'position': 0.8}
    },
    'Social': {
        'Healthcare': {'position': 1.0},
        'Education': {'position': 1.0},
        'CurriculumControl': {'position': 1.0},
        'Housing': {'position': 1.0},
        'Indigenous': {'position': 1.0},
        'Immigration': {'position': 0.2},
        'LGBTQ': {'position': 0.9},
        'Drugs': {'position': 0.8},
        'DEI': {'position': 0.8}
    },
    'Environment': {
        'Emissions': {'position': 0.9},
        'CarbonTax': {'position': 0.8},
        'FossilFuels': {'position': 0.7},
        'GreenInvestment': {'position': 0.9}
    },
    'Foreign': {
        'SpendingM': {'position': -0.5},
        'RefugeePolicy': {'position': 0.5},
        'Aid': {'position': 0.5},
        'Trade': {'position': -0.3},
        'IsraelPalestine': {'position': 0.8},
        'UkraineRussia': {'position': 0.7}
    },
    'Justice': {
        'CriminalJustice': {'position': 0.8},
        'FreeSpeech': {'position': 0.0},
        'PoliceReform': {'position': 0.7},
        'ReligiousLiberty': {'position': 0.0}
    },
    'Science': {
        'Research': {'position': 0.8},
        'AI': {'position': 0.9},
        'Internet': {'position': 0.0},
        'Privacy': {'position': 0.9}
    },
    'Governance': {
        'Electoral': {'position': 0.9},
        'Transparency': {'position': 0.7},
        'Federalism': {'position': 0.0}
    }
}

# %%
# save 
filename = data_path + 'GPT_ndp_platform.pkl'

with open(filename, 'wb') as f:
    pickle.dump(updated_ndp_positions, f)
